# %%
'''
Read the msm top features and the msw top features in separate dataframes
Include an 'Other' column
Include a 'Target' column
Merge the two dataframes by columns
Classify Feature Importance using Random Forest.

'''
# Out:
# "\nRead the msm top features and the msw top features in separate dataframes\nInclude an 'Other' column\nInclude a 'Target' column\nMerge the two dataframes by columns\nClassify Feature Importance using Random Forest.\n\n"

# %%
#This file contains the interaction between msm and msw variables

import pandas as pd
df_msm = pd.read_csv('msm_tt_rel_abundance.csv')
df_msw = pd.read_csv('msw_tt_rel_abundance.csv')
df_msm.head()
# Out:
#    Unnamed: 0  d5__lactobacillus  d5__corynebacterium1  d5__gardnerella  \
# 0           0           0.551265              0.092360         0.050879
# 1           1           0.454743              0.212829         0.059286
# 2           2           0.216172              0.093996         0.041399
# 3           3           0.480576              0.219067         0.055967
# 4           4           0.210626              0.154954         0.038907
#
#    d5__sneathia  d5__finegoldia  d5__anaerococcus  d5__peptoniphilus  \
# 0      0.049012        0.016895          0.034048           0.023878
# 1      0.030143        0.063200          0.017686           0.031971
# 2      0.120857        0.011143          0.019226           0.009627
# 3      0.023484        0.015089          0.012401           0.022442
# 4      0.070119        0.010531          0.115957           0.030491
#
#    d5__staphylococcus  d5__streptococcus  d5__veillonella     Other
# 0            0.015029           0.029671         0.004763  0.132201
# 1            0.021171           0.016771         0.005800  0.086400
# 2            0.018468           0.014511         0.107834  0.346768
# 3            0.022387           0.011742         0.006365  0.130480
# 4            0.082203           0.048628         0.007358  0.230226

# %%
## modify the df_msm dataframe

feature_list = ['d5__lactobacillus','d5__corynebacterium1','d5__gardnerella','d5__sneathia','d5__finegoldia','d5__anaerococcus','d5__peptoniphilus','d5__staphylococcus','d5__streptococcus',
            'd5__veillonella','Other','Target']  

df_msm['Target']=1
df_msm_mod = df_msm[feature_list]
df_msm_mod.head()
# Out:
#    d5__lactobacillus  d5__corynebacterium1  d5__gardnerella  d5__sneathia  \
# 0           0.551265              0.092360         0.050879      0.049012
# 1           0.454743              0.212829         0.059286      0.030143
# 2           0.216172              0.093996         0.041399      0.120857
# 3           0.480576              0.219067         0.055967      0.023484
# 4           0.210626              0.154954         0.038907      0.070119
#
#    d5__finegoldia  d5__anaerococcus  d5__peptoniphilus  d5__staphylococcus  \
# 0        0.016895          0.034048           0.023878            0.015029
# 1        0.063200          0.017686           0.031971            0.021171
# 2        0.011143          0.019226           0.009627            0.018468
# 3        0.015089          0.012401           0.022442            0.022387
# 4        0.010531          0.115957           0.030491            0.082203
#
#    d5__streptococcus  d5__veillonella     Other  Target
# 0           0.029671         0.004763  0.132201       1
# 1           0.016771         0.005800  0.086400       1
# 2           0.014511         0.107834  0.346768       1
# 3           0.011742         0.006365  0.130480       1
# 4           0.048628         0.007358  0.230226       1

# %%
## modify the df_msw dataframe

feature_list = ['d5__lactobacillus','d5__corynebacterium1','d5__gardnerella','d5__sneathia','d5__finegoldia','d5__anaerococcus','d5__peptoniphilus','d5__staphylococcus','d5__streptococcus',
            'd5__veillonella','Other','Target']  

df_msw['Target']=0
df_msw_mod = df_msw[feature_list]
df_msw_mod.head()
# Out:
#    d5__lactobacillus  d5__corynebacterium1  d5__gardnerella  d5__sneathia  \
# 0           0.000106              0.398181         0.340459      0.000181
# 1           0.000143              0.756168         0.000119      0.000143
# 2           0.000060              0.031643         0.000090      0.000105
# 3           0.000181              0.029943         0.492928      0.076144
# 4           0.000053              0.132611         0.001395      0.345781
#
#    d5__finegoldia  d5__anaerococcus  d5__peptoniphilus  d5__staphylococcus  \
# 0        0.002206          0.005182           0.004366            0.141685
# 1        0.000500          0.000417           0.000345            0.217087
# 2        0.000992          0.006942           0.000841            0.020269
# 3        0.001172          0.003092           0.001063            0.033651
# 4        0.002883          0.288749           0.002484            0.004822
#
#    d5__streptococcus  d5__veillonella     Other  Target
# 0           0.000453         0.000151  0.107031       0
# 1           0.000345         0.000071  0.024661       0
# 2           0.836496         0.000075  0.102487       0
# 3           0.000374         0.265246  0.096206       0
# 4           0.079869         0.095280  0.046072       0

# %%
## merge the two dataframes by columns

result = df_msm_mod.append(df_msw_mod)

# %%
result = result.sample(frac=1)
y = result['Target']
X = result.drop(['Target'],axis=1)


result.to_csv('combined_msm_msw.csv')
X.head()
# Out:
#     d5__lactobacillus  d5__corynebacterium1  d5__gardnerella  d5__sneathia  \
# 36           0.470148              0.204077         0.070227      0.024789
# 21           0.524303              0.194886         0.054100      0.025078
# 12           0.365456              0.200652         0.093319      0.018822
# 33           0.069900              0.393220         0.010483      0.000000
# 25           0.000000              0.695242         0.000000      0.000000
#
#     d5__finegoldia  d5__anaerococcus  d5__peptoniphilus  d5__staphylococcus  \
# 36        0.010567          0.020496           0.023820            0.025361
# 21        0.029077          0.013926           0.017326            0.025677
# 12        0.008687          0.164379           0.019459            0.019864
# 33        0.099498          0.130822           0.028343            0.014250
# 25        0.006472          0.052703           0.001123            0.190404
#
#     d5__streptococcus  d5__veillonella     Other
# 36           0.019923         0.018030  0.112562
# 21           0.010962         0.015313  0.089351
# 12           0.009536         0.007259  0.092566
# 33           0.017577         0.008726  0.227181
# 25           0.000033         0.000000  0.054024

# %%
## split the data set

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.33,random_state=42)

from sklearn.naive_bayes import GaussianNB
clf = GaussianNB()
scores = cross_val_score(clf,X,y,cv=5)

# clf.fit(x_train,y_train)
# y_pred = clf.predict(x_test)

# print(clf.score(x_test,y_test))
# print(confusion_matrix(y_test,y_pred))


print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# Accuracy: 0.78 (+/- 0.33)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score

lreg = LogisticRegression(solver='lbfgs').fit(x_train,y_train)
scores = cross_val_score(lreg,X,y,cv=5)
# scores
# print(lreg.score(x_test,y_test))
# y_pred = lreg.predict(x_test)
# print(confusion_matrix(y_test,y_pred))

print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# Accuracy: 0.77 (+/- 0.21)

# %%
### Random Forest Feature Importance

from sklearn.ensemble import RandomForestClassifier
rand_for = RandomForestClassifier(n_estimators = 10,max_depth=2, random_state=0)


rand_for.fit(x_train,y_train)
# scores = cross_val_score(rand_for,X,y,cv=5)
# print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# # print(rand_for.feature_importances_)

print(rand_for.score(x_test,y_test))
y_pred = rand_for.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print(rand_for.feature_importances_)
# print(X.columns)
# print(X.columns)
# Out:
# 0.8620689655172413
# [[10  1]
#  [ 3 15]]
# [0.25523468 0.         0.13927066 0.06959416 0.05404192 0.05648204
#  0.18521295 0.05025731 0.06083007 0.12907621 0.        ]

# %%
## Linear Regression

from sklearn.linear_model import LinearRegression
reg = LinearRegression()
scores = cross_val_score(reg,X,y,cv=5)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# Accuracy: 0.29 (+/- 0.52)

# %%
### check for feature importance in lactobacillus
import seaborn as sns
import matplotlib.pyplot as plt


sns.lmplot(x='d5__lactobacillus',y='Target',data=result,logistic=True)
plt.title('Log Regression Lactobacillus vs Target')

plt.show()
